# %%
import codecs
import os, sys, re, inspect


# note that the json file format is from 
# - https://github.com/krikit/annie
# - 2016년 한글 및 한국어 정보처리 학술대회 :  "2016년 엑소브레인 V2.0 & 울산대학교 말뭉치"라는 명칭의 CD로 배포
#
def convert(fn,NE_list):
    
    NE_parser=[]
    def syntax_change(line,result):
        for part in result:
            text,tag = part[1:-1].split(':')
            new_part = '<%s>%s</%s>'%(tag,text,tag)
            line = line.replace(part,new_part)
        return line
        
    def _filter(lines,tag):
        filtered_sents = []
        for line in lines:
            line = line.strip()
            word = re.compile('<[^>]*:%s>'%tag)
            result = word.findall(line)
            if result:
                print(result)
                line = syntax_change(line,result)
                NE_parser.append(result)
            filtered_sents.append(line)
        return filtered_sents
    
    with open(fn, 'r', encoding='utf-8') as f: 
        lines = f.readlines()
        for tag in NE_list:
            lines = _filter(lines,tag)
        out_fn = os.path.join(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))), 'trip.xml.txt') 
        with codecs.open(out_fn, 'w', encoding='utf-8') as f:
            for line in lines:
                print(line, file=f)

    

if __name__ == '__main__':
    fn = 'trip.txt'
    NE_list = ['AC','DT','LC','PU','PR','WT']
    convert(fn,NE_list)
# Out:
# ['<4인가족:AC>']
# ['<대학생:AC>', '<직장인:AC>']
# ['<가족들:AC>']
# ['<가족:AC>']
# ['<친구:AC>']
# ['<아이:AC>']
# ['<가족:AC>']
# ['<혼자:AC>']
# ['<여자혼자:AC>']
# ['<와이프:AC>']
# ['<부모님:AC>']
# ['<남자친구:AC>']
# ['<어머님:AC>']
# ['<친구:AC>']
# ['<가족:AC>']
# ['<혼자:AC>']
# ['<가족:AC>']
# ['<친구들:AC>']
# ['<친남매:AC>']
# ['<친언니:AC>']
# ['<부모님:AC>']
# ['<혼자:AC>']
# ['<친구:AC>']
# ['<친한언니:AC>']
# ['<가족:AC>']
# ['<혼자:AC>']
# ['<가족:AC>', '<엄마,저, 남동생:AC>']
# ['<어머니:AC>']
# ['<친한언니:AC>']
# ['<남자4명:AC>']
# ['<가족:AC>']
# ['<식구:AC>']
# ['<가족:AC>']
# ['<여자:AC>']
# ['<아이들:AC>']
# ['<엄마:AC>']
# ['<가족:AC>']
# ['<친구들:AC>']
# ['<여자친구:AC>']
# ['<엄마:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<대가족:AC>']
# ['<부모님:AC>', '<저희애:AC>']
# ['<여자 혼자:AC>']
# ['<남자친구:AC>']
# ['<남자 둘:AC>']
# ['<친구들:AC>']
# ['<친구:AC>']
# ['<아기:AC>']
# ['<여자 혼자:AC>']
# ['<여자 혼자:AC>']
# ['<여자 둘:AC>']
# ['<친구:AC>']
# ['<딸:AC>']
# ['<절친:AC>']
# ['<아버지:AC>', '<아들:AC>']
# ['<남자친구:AC>']
# ['<남자둘:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<모녀:AC>']
# ['<친구:AC>']
# ['<가족:AC>']
# ['<아빠:AC>']
# ['<친구:AC>']
# ['<가족:AC>']
# ['<부모님:AC>']
# ['<여성 혼자:AC>']
# ['<부모님:AC>', '<동생:AC>']
# ['<부모님:AC>']
# ['<여자혼자:AC>']
# ['<남자3명:AC>']
# ['<여자3명:AC>']
# ['<여자친구:AC>']
# ['<세딸들:AC>']
# ['<애들:AC>']
# ['<아이:AC>']
# ['<아이:AC>']
# ['<가족:AC>']
# ['<어머니:AC>']
# ['<어머니:AC>']
# ['<어머니:AC>']
# ['<엄마랑:AC>']
# ['<엄마랑:AC>']
# ['<부모님:AC>', '<동생:AC>']
# ['<가족:AC>']
# ['<부모님:AC>', '<어른:AC>', '<초등생:AC>']
# ['<부모님:AC>']
# ['<부모님:AC>']
# ['<부모님:AC>']
# ['<어머니:AC>']
# ['<어머니:AC>']
# ['<가족:AC>', '<어른:AC>', '<초등:AC>']
# ['<부모님:AC>']
# ['<가족:AC>']
# ['<남자친구:AC>']
# ['<동생:AC>']
# ['<가족:AC>']
# ['<엄마랑:AC>']
# ['<엄마:AC>']
# ['<신랑:AC>']
# ['<친구들끼리:AC>']
# ['<친구들과:AC>']
# ['<남자혼자:AC>']
# ['<친구한놈:AC>']
# ['<엄마랑:AC>']
# ['<모녀:AC>']
# ['<아이:AC>']
# ['<혼자:AC>']
# ['<아버지와:AC>']
# ['<4인가족:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<가족:AC>']
# ['<혼자:AC>']
# ['<친구랑:AC>']
# ['<친구:AC>']
# ['<친구가:AC>']
# ['<가족:AC>']
# ['<부모님:AC>']
# ['<혼자:AC>']
# ['<엄마:AC>', '<딸:AC>']
# ['<엄마:AC>']
# ['<친구들이랑:AC>']
# ['<부모님:AC>']
# ['<아빠:AC>']
# ['<딸:AC>']
# ['<남자친구:AC>']
# ['<가족:AC>', '<애들:AC>']
# ['<4인 가족:AC>', '<애들:AC>']
# ['<엄마:AC>']
# ['<엄마:AC>']
# ['<친구와:AC>']
# ['<친구두명:AC>']
# ['<남자2명:AC>']
# ['<혼자:AC>']
# ['<엄마:AC>']
# ['<엄마:AC>']
# ['<아들:AC>', '<가족:AC>']
# ['<아들:AC>']
# ['<엄마:AC>']
# ['<부모님:AC>', '<아들:AC>', '<가족:AC>']
# ['<여자애들:AC>']
# ['<4인가족:AC>']
# ['<친구한명:AC>']
# ['<가족:AC>']
# ['<부모님:AC>']
# ['<딸:AC>']
# ['<아들:AC>']
# ['<아빠와:AC>', '<아들:AC>']
# ['<엄마:AC>']
# ['<가족:AC>', '<엄마:AC>']
# ['<엄마:AC>']
# ['<엄마:AC>']
# ['<혼자:AC>']
# ['<가족:AC>']
# ['<아버지:AC>', '<동생:AC>']
# ['<초등생:AC>']
# ['<아이:AC>']
# ['<딸:AC>']
# ['<부모님:AC>']
# ['<부모님:AC>']
# ['<가족:AC>']
# ['<아이:AC>']
# ['<아이:AC>']
# ['<어머니:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<동생:AC>']
# ['<엄마:AC>']
# ['<친구랑:AC>']
# ['<혼자:AC>']
# ['<신랑:AC>']
# ['<가족:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<남자친구:AC>']
# ['<커플:AC>']
# ['<여자친구:AC>']
# ['<가족:AC>']
# ['<여자친구:AC>']
# ['<혼자:AC>']
# ['<친구랑:AC>']
# ['<친구들이랑:AC>']
# ['<엄마:AC>']
# ['<아이:AC>']
# ['<부모님:AC>']
# ['<남자친구:AC>']
# ['<혼자:AC>']
# ['<여자 셋:AC>']
# ['<아들:AC>', '<엄마:AC>']
# ['<엄마:AC>']
# ['<친구랑:AC>']
# ['<친구와:AC>']
# ['<가족:AC>']
# ['<아이:AC>', '<부모님:AC>']
# ['<동생:AC>']
# ['<엄마:AC>', '<아빠:AC>']
# ['<혼자:AC>']
# ['<아들:AC>', '<아빠:AC>']
# ['<동생:AC>']
# ['<친구들이랑:AC>']
# ['<친구들끼리:AC>']
# ['<가족:AC>']
# ['<부모님:AC>']
# ['<가족:AC>']
# ['<엄마:AC>']
# ['<가족:AC>']
# ['<가족:AC>']
# ['<가족:AC>']
# ['<커플:AC>']
# ['<커플:AC>']
# ['<부모님:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<가족:AC>']
# ['<가족:AC>']
# ['<2인:AC>']
# ['<동생:AC>']
# ['<가족:AC>']
# ['<언니:AC>']
# ['<부모님:AC>', '<가족:AC>']
# ['<부모님:AC>', '<할머니:AC>']
# ['<친구랑:AC>']
# ['<혼자:AC>']
# ['<엄마:AC>']
# ['<남자친구:AC>']
# ['<남자친구:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<혼자:AC>']
# ['<아이:AC>', '<가족:AC>']
# ['<가족:AC>']
# ['<친구들끼리:AC>']
# ['<가족:AC>']
# ['<가족:AC>']
# ['<친구랑:AC>']
# ['<커플:AC>']
# ['<친구:AC>']
# ['<혼자:AC>']
# ['<가족:AC>', '<가족:AC>']
# ['<가족:AC>', '<가족:AC>']
# ['<가족:AC>']
# ['<엄마랑:AC>']
# ['<부모님:AC>']
# ['<부모님:AC>']
# ['<혼자:AC>']
# ['<남자친구:AC>']
# ['<가족:AC>']
# ['<가족:AC>']
# ['<부모님:AC>']
# ['<1월달:DT>', '<2월달:DT>']
# ['<2~3월:DT>']
# ['<6월말 에서 7월초:DT>']
# ['<여름:DT>']
# ['<12월말:DT>']
# ['<8월:DT>']
# ['<여름:DT>']
# ['<7월~8월:DT>']
# ['<올해 5월:DT>']
# ['<7월달쯤:DT>']
# ['<8월 넷째주:DT>']
# ['<7월달:DT>']
# ['<겨울방학:DT>']
# ['<5월:DT>']
# ['<7월:DT>']
# ['<여름:DT>']
# ['<6월:DT>']
# ['<4,5월:DT>']
# ['<여름휴가:DT>', '<8월 달:DT>']
# ['<7~8월:DT>']
# ['<3월:DT>', '<4월:DT>']
# ['<6월:DT>']
# ['<여름휴가:DT>', '<8월달:DT>']
# ['<4월말:DT>']
# ['<9월중순:DT>', '<9월 말:DT>']
# ['<1월:DT>']
# ['<10월:DT>']
# ['<6월 말:DT>']
# ['<12월중순:DT>']
# ['<9월달:DT>']
# ['<7월달:DT>']
# ['<12월:DT>']
# ['<8월:DT>']
# ['<9월:DT>']
# ['<3월중후반:DT>']
# ['<9월13일:DT>']
# ['<9월 중순:DT>']
# ['<7월 중순:DT>']
# ['<여름:DT>']
# ['<5월:DT>', '<6월:DT>']
# ['<5월:DT>']
# ['<5월 18일:DT>']
# ['<다음주:DT>']
# ['<7-8월:DT>']
# ['<9-10월:DT>']
# ['<겨울:DT>']
# ['<겨울:DT>']
# ['<5월:DT>']
# ['<8월:DT>']
# ['<2월:DT>']
# ['<6월달:DT>']
# ['<4월:DT>']
# ['<12월:DT>']
# ['<여름:DT>']
# ['<겨울:DT>']
# ['<9월25일:DT>']
# ['<10월:DT>']
# ['<9월:DT>']
# ['<8월:DT>']
# ['<9월:DT>']
# ['<8월:DT>', '<7월말:DT>']
# ['<8월에:DT>']
# ['<6월:DT>', '<7월:DT>']
# ['<10월:DT>']
# ['<10월:DT>']
# ['<1월:DT>']
# ['<6월:DT>']
# ['<8월:DT>']
# ['<2월 말:DT>', '<3월:DT>']
# ['<7월:DT>']
# ['<7월:DT>']
# ['<7월:DT>', '<6월:DT>']
# ['<9월말:DT>']
# ['<여름:DT>']
# ['<1월~2월달쯤:DT>']
# ['<7월:DT>', '<8월:DT>']
# ['<7월:DT>', '<8월:DT>']
# ['<7월:DT>']
# ['<8월:DT>']
# ['<6월:DT>']
# ['<6월:DT>']
# ['<겨울:DT>', '<12월:DT>']
# ['<1월:DT>']
# ['<6월:DT>']
# ['<겨울:DT>']
# ['<8월:DT>']
# ['<1월:DT>']
# ['<2월 말:DT>']
# ['<12월 초:DT>']
# ['<7월:DT>']
# ['<12월:DT>']
# ['<6월:DT>']
# ['<8월:DT>']
# ['<여름철:DT>']
# ['<3월:DT>']
# ['<3월:DT>']
# ['<3월:DT>']
# ['<6월말:DT>']
# ['<12월:DT>']
# ['<5월:DT>']
# ['<5월:DT>']
# ['<2월달:DT>']
# ['<겨울:DT>']
# ['<8월에:DT>']
# ['<8월:DT>']
# ['<5월:DT>']
# ['<여름휴가때:DT>']
# ['<8월:DT>']
# ['<7월:DT>']
# ['<7월:DT>']
# ['<1월:DT>']
# ['<6월:DT>']
# ['<6월:DT>']
# ['<8월:DT>', '<9월:DT>']
# ['<5월:DT>']
# ['<9월:DT>']
# ['<5월:DT>']
# ['<여름 휴가:DT>']
# ['<12월:DT>']
# ['<8월:DT>']
# ['<6월:DT>']
# ['<4월:DT>', '<5월:DT>']
# ['<5월:DT>']
# ['<5월:DT>']
# ['<2월:DT>']
# ['<8월:DT>']
# ['<3월:DT>']
# ['<8월:DT>']
# ['<6월:DT>', '<7월:DT>']
# ['<7월:DT>']
# ['<6월:DT>']
# ['<8월에:DT>']
# ['<10월:DT>']
# ['<7월:DT>']
# ['<7월말:DT>', '<8월:DT>']
# ['<겨울:DT>']
# ['<1월:DT>']
# ['<5~6월:DT>']
# ['<겨울:DT>']
# ['<겨울:DT>']
# ['<8월:DT>']
# ['<10월:DT>']
# ['<겨울:DT>']
# ['<1월:DT>']
# ['<10월:DT>']
# ['<여름:DT>']
# ['<겨울:DT>']
# ['<<12월:DT>']
# ['<7월:DT>', '<<8월:DT>']
# ['<7~9월:DT>']
# ['<3월:DT>', '<5월:DT>']
# ['<1월:DT>']
# ['<3월:DT>']
# ['<8월:DT>']
# ['<12월초:DT>']
# ['<8월초:DT>']
# ['<8월초:DT>']
# ['<1월:DT>']
# ['<1월:DT>']
# ['<6월:DT>']
# ['<4월:DT>']
# ['<1월:DT>']
# ['<1월:DT>']
# ['<10월:DT>']
# ['<7월:DT>', '<8월:DT>']
# ['<7월:DT>']
# ['<1월:DT>']
# ['<9월:DT>']
# ['<9월:DT>']
# ['<9월:DT>']
# ['<6월:DT>']
# ['<7월:DT>', '<6월:DT>']
# ['<5월:DT>']
# ['<4월:DT>']
# ['<7월:DT>']
# ['<겨울:DT>', '<겨울:DT>']
# ['<8월:DT>']
# ['<1월:DT>']
# ['<1월:DT>']
# ['<겨울:DT>']
# ['<겨울:DT>']
# ['<1월:DT>']
# ['<1월:DT>']
# ['<1월:DT>']
# ['<다낭:LC>', '<푸켓:LC>', '<괌:LC>', '<마카오:LC>', '<홍콩:LC>']
# ['<세부:LC>', '<방콕:LC>']
# ['<싱가포르:LC>', '<말레이시아:LC>', '<대만:LC>', '<베트남:LC>']
# ['<일본:LC>', '<대만:LC>', '<북경:LC>']
# ['<코타키나발루:LC>']
# ['<동남아:LC>', '<푸켓:LC>']
# ['<동남아:LC>']
# ['<파타야:LC>', '<푸켓:LC>', '<코타키나발루:LC>', '<일본:LC>', '<중국:LC>']
# ['<괌:LC>']
# ['<일본:LC>']
# ['<훗카이도:LC>']
# ['<홍콩:LC>', '<일본:LC>']
# ['<괌:LC>', '<태국:LC>', '<다낭:LC>']
# ['<일본:LC>']
# ['<마카오:LC>']
# ['<베트남:LC>', '<일본:LC>', '<중국:LC>']
# ['<마카오:LC>']
# ['<두바이:LC>', '<호주:LC>', '<뉴질랜드:LC>']
# ['<베트남은:LC>']
# ['<동남아:LC>', '<라오스:LC>', '<베트남:LC>', '<방콕:LC>']
# ['<파타야:LC>', '<푸켓:LC>']
# ['<동남아:LC>']
# ['<동남아:LC>']
# ['<유럽:LC>']
# ['<오키나와:LC>', '<대만:LC>', '<사이판:LC>']
# ['<라오스:LC>']
# ['<보라카이:LC>', '<방콕:LC>']
# ['<도쿄:LC>', '<홍콩:LC>']
# ['<일본:LC>']
# ['<일본:LC>']
# ['<대만:LC>', '<일본:LC>']
# ['<방콕:LC>']
# ['<동남아:LC>']
# ['<다낭:LC>', '<방콕:LC>', '<타이베이:LC>', '<괌:LC>', '<홍콩:LC>', '<괌:LC>']
# ['<홍콩:LC>']
# ['<일본:LC>']
# ['<일본:LC>']
# ['<베트남:LC>']
# ['<베트남:LC>']
# ['<베트남:LC>']
# ['<베트남:LC>']
# ['<베트남:LC>']
# ['<일본:LC>', '<대만:LC>', '<다낭:LC>', '<코타키:LC>', '<발루:LC>']
# ['<일본:LC>']
# ['<일본:LC>']
# ['<일본:LC>', '<오키나와:LC>', '<오사카:LC>']
# ['<다낭:LC>']
# ['<일본:LC>', '<대만:LC>', '<다낭:LC>', '<코타키:LC>', '<발루:LC>']
# ['<미국:LC>', '<하와이:LC>', '<일본:LC>', '<중국:LC>', '<대만:LC>', '<필리핀:LC>']
# ['<베트남:LC>', '<인도네시아:LC>', '<두바이:LC>', '<터키:LC>', '<영국:LC>', '<스페인:LC>', '<프랑스:LC>', '<스위스:LC>']
# ['<일본:LC>', '<큐슈:LC>', '<북해도:LC>']
# ['<일본:LC>']
# ['<홍콩:LC>', '<마카오:LC>']
# ['<괌:LC>', '<보라카이:LC>', '<북해:LC>']
# ['<보라카이:LC>']
# ['<마카오:LC>']
# ['<태국:LC>']
# ['<스위스:LC>', '<유럽:LC>']
# ['<일본:LC>', '<태국:LC>', '<중국:LC>']
# ['<일본:LC>', '<훗카이도:LC>']
# ['<대만:LC>']
# ['<중국:LC>']
# ['<홍콩:LC>']
# ['<동남아:LC>']
# ['<호주:LC>', '<뉴질랜드:LC>']
# ['<남미:LC>', '<볼리비아:LC>', '<브라질:LC>', '<아르헨티나:LC>']
# ['<동남아:LC>']
# ['<후쿠오카:LC>', '<홍콩:LC>']
# ['<태국:LC>']
# ['<홍콩:LC>', '<중국:LC>', '<마카오:LC>']
# ['<호주:LC>']
# ['<동남아:LC>']
# ['<미주:LC>', '<유럽:LC>']
# ['<태국:LC>', '<베트남:LC>']
# ['<중국:LC>', '<항저우:LC>']
# ['<일본:LC>', '<중국:LC>']
# ['<싱가폴:LC>', '<중국:LC>']
# ['<오사카:LC>', '<도쿄:LC>', '<홍콩:LC>', '<대만:LC>', '<베트남:LC>', '<중국:LC>']
# ['<사진:LC>']
# ['<유럽:LC>']
# ['<태국:LC>', '<대만:LC>']
# ['<일본:LC>', '<일본:LC>']
# ['<일본:LC>']
# ['<대만:LC>', '<일본:LC>', '<태국:LC>']
# ['<일본:LC>']
# ['<도쿄:LC>', '<대만:LC>']
# ['<유럽:LC>', '<동남아:LC>', '<중국:LC>']
# ['<중국:LC>']
# ['<사이판:LC>', '<발리:LC>']
# ['<보라카이:LC>']
# ['<동남아:LC>']
# ['<동남아:LC>']
# ['<동남아:LC>', '<일본:LC>']
# ['<일본:LC>']
# ['<일본:LC>', '<후쿠오카:LC>']
# ['<태국:LC>', '<홍콩:LC>', '<마카오:LC>', '<일본:LC>', '<대만:LC>']
# ['<동남아:LC>']
# ['<스위스:LC>']
# ['<방콕:LC>']
# ['<필리핀:LC>', '<보라카이:LC>']
# ['<대만:LC>']
# ['<동남아:LC>']
# ['<오사카:LC>']
# ['<동남아:LC>']
# ['<후쿠오카:LC>']
# ['<일본:LC>', '<오사카:LC>']
# ['<오사카:LC>']
# ['<일본:LC>', '<홍콩:LC>']
# ['<동남아:LC>']
# ['<베트남:LC>', '<홍콩:LC>']
# ['<타이완:LC>']
# ['<스위스:LC>', '<호주:LC>']
# ['<중국:LC>', '<일본:LC>', '<괌:LC>']
# ['<일본:LC>', '<홍콩:LC>']
# ['<세부:LC>', '<보라카이:LC>', '<미얀마:LC>']
# ['<힐링:PU>']
# ['<휴양:PU>', '<유흥:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<휴양:PU>', '<관광:PU>', '<쇼핑:PU>']
# ['<열기구:PU>']
# ['<마음에 정리:PU>', '<감성팔이:PU>']
# ['<휴양지:PU>', '<관광지:PU>']
# ['<추억:PU>', '<이색경험:PU>']
# ['<휴양지:PU>', '<액티비티:PU>', '<놀기 좋은 곳:PU>']
# ['<힐링:PU>']
# ['<힐링여행:PU>']
# ['<자연:PU>']
# ['<구경:PU>', '<휴양:PU>']
# ['<유흥:PU>']
# ['<휴양지:PU>']
# ['<볼거리:PU>']
# ['<바다:PU>']
# ['<휴양:PU>', '<체험:PU>', '<음식:PU>']
# ['<날씨:PU>', '<물가:PU>']
# ['<치안:PU>', '<추억:PU>']
# ['<구경거리:PU>']
# ['<추억:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<관광명소:PU>', '<볼거리:PU>', '<즐길거리:PU>']
# ['<휴양:PU>']
# ['<안전:PU>']
# ['<구경:PU>']
# ['<휴식:PU>', '<관광:PU>']
# ['<교통:PU>', '<휴식:PU>']
# ['<안전:PU>']
# ['<교통:PU>']
# ['<해수욕장:PU>']
# ['<휴양지:PU>']
# ['<휴식:PU>']
# ['<날씨:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<휴양:PU>', '<휴양:PU>']
# ['<관광:PU>']
# ['<휴양:PU>']
# ['<쇼핑:PU>', '<바다:PU>']
# ['<힐링:PU>', '<쇼핑:PU>']
# ['<놀이공원:PU>']
# ['<힐링:PU>']
# ['<볼거 많은:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<관광:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<구경:PU>']
# ['<구경:PU>', '<맛있는음식:PU>', '<관광:PU>']
# ['<맛집:PU>', '<먹거리:PU>']
# ['<휴식:PU>']
# ['<아기자기한 마을:PU>', '<예쁜 풍경:PU>']
# ['<문화:PU>']
# ['<쇼핑:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<힐링:PU>', '<생각정리:PU>', '<휴식:PU>']
# ['<구경거리:PU>', '<맛집:PU>', '<마사지:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<관광:PU>']
# ['<역사:PU>', '<활동적:PU>']
# ['<쉬면서:PU>', '<구경거리:PU>']
# ['<수영장:PU>', '<바다:PU>', '<물놀이:PU>']
# ['<트레킹:PU>', '<서핑:PU>', '<모험:PU>']
# ['<관광:PU>']
# ['<휴양:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<모험:PU>', '<문명체험:PU>']
# ['<휴양:PU>']
# ['<휴양:PU>']
# ['<구경:PU>', '<맛있는음식:PU>', '<휴양:PU>']
# ['<관광:PU>', '<관광:PU>']
# ['<휴양:PU>', '<쇼핑:PU>']
# ['<휴양:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<휴양:PU>', '<수영장:PU>', '<먹고:PU>', '<즐기는:PU>']
# ['<관광:PU>', '<자연:PU>', '<구경:PU>']
# ['<관광:PU>']
# ['<관광:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<자연:PU>', '<마사지:PU>', '<음식들:PU>', '<물놀이:PU>', '<힐링:PU>', '<쉼:PU>', '<맑은공기:PU>']
# ['<힐링:PU>', '<휴식:PU>']
# ['<쇼핑:PU>']
# ['<휴양:PU>']
# ['<관광:PU>', '<경치:PU>']
# ['<구경거리:PU>', '<맛있는 음식:PU>']
# ['<쇼핑:PU>', '<구경:PU>', '<풍경:PU>', '<역사:PU>']
# ['<관광:PU>']
# ['<바다:PU>']
# ['<스노쿨링:PU>', '<액티비티:PU>']
# ['<바다:PU>', '<물놀이:PU>']
# ['<스포츠:PU>', '<놀거리:PU>']
# ['<장기:PU>', '<보름:PU>']
# ['<힐링:PU>', '<먹고:PU>', '<쇼핑:PU>', '<구경:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<휴양:PU>']
# ['<관광:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<휴양:PU>', '<관광:PU>', '<액티비티:PU>']
# ['<휴양:PU>']
# ['<휴양:PU>']
# ['<물놀이:PU>', '<관광:PU>']
# ['<힐링:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<휴양:PU>', '<관광:PU>']
# ['<관광:PU>']
# ['<바다:PU>', '<물놀이:PU>']
# ['<관광:PU>']
# ['<휴양:PU>', '<볼거리:PU>']
# ['<관광:PU>', '<휴양:PU>']
# ['<볼거리:PU>', '<먹거리:PU>']
# ['<관광:PU>', '<기념품:PU>', '<먹거리:PU>']
# ['<먹거리:PU>', '<쇼핑:PU>', '<건축물:PU>', '<자연경관:PU>', '<볼거리:PU>']
# ['<관광:PU>', '<먹고:PU>', '<쇼핑:PU>']
# ['<자연:PU>', '<휴양:PU>']
# ['<3박 4일:PR>']
# ['<3박4일:PR>']
# ['<1주일:PR>']
# ['<2박3일:PR>', '<3박4일:PR>']
# ['<3박5일:PR>', '<4박5일:PR>']
# ['<8월 15일부터 19일까지:PR>', '<5일동안:PR>']
# ['<4~5일 정도:PR>']
# ['<3박4일:PR>', '<20일 정도:PR>']
# ['<3박4일:PR>', '<4박 5일:PR>']
# ['<3박4일:PR>']
# ['<6일~10일:PR>']
# ['<9월29일~10월3일:PR>', '<4박5일:PR>']
# ['<4~5박:PR>']
# ['<2주 정도:PR>']
# ['<5~7일:PR>']
# ['<7일에서 10일:PR>']
# ['<3~5일:PR>']
# ['<6박 8일:PR>']
# ['<3박4일:PR>', '<4박5일:PR>']
# ['<3박5일:PR>', '<4박5일:PR>']
# ['<4박 5일:PR>']
# ['<3박4일?5일?:PR>']
# ['<3박4일:PR>']
# ['<4일또는 5일간:PR>']
# ['<3박4일:PR>']
# ['<9월3일부터 9월7일:PR>']
# ['<3박4일:PR>']
# ['<3박:PR>', '<4박5일:PR>']
# ['<4박5일:PR>']
# ['<2박3일:PR>']
# ['<3박4일:PR>']
# ['<2박3일:PR>', '<3박4일:PR>']
# ['<3박4일:PR>']
# ['<3일부터 7일까지:PR>']
# ['<3박4일:PR>', '<4박5일:PR>']
# ['<2주:PR>']
# ['<2박 3일:PR>', '<3박 4일:PR>']
# ['<4박5일:PR>']
# ['<4박5일:PR>']
# ['<3박4일:PR>', '<4박5일:PR>']
# ['<3박4일:PR>', '<4박 5일:PR>']
# ['<일주일:PR>']
# ['<6박 7일:PR>']
# ['<4박 5일:PR>', '<4박6일:PR>']
# ['<3박5일:PR>']
# ['<3박~4박5일:PR>']
# ['<5~6일:PR>']
# ['<3박 5일:PR>']
# ['<4박이나:PR>', '<3박:PR>']
# ['<3박 4일:PR>', '<5일정도:PR>']
# ['<1년:PR>']
# ['<1년:PR>']
# ['<7일~10일:PR>']
# ['<3박 5일:PR>']
# ['<3박 4일:PR>']
# ['<3박 4일:PR>', '<2박 3일:PR>']
# ['<25일정도:PR>']
# ['<5일:PR>']
# ['<5일 이내:PR>']
# ['<4박 5일정도:PR>']
# ['<3박4일:PR>']
# ['<4일:PR>', '<5일:PR>', '<한달:PR>']
# ['<나흘:PR>']
# ['<총 14일:PR>']
# ['<7박 8일:PR>']
# ['<3박4일:PR>']
# ['<3박4일:PR>', '<4박 5일:PR>']
# ['<5일:PR>', '<4박5일:PR>', '<3박 4일:PR>']
# ['<6박 7일:PR>', '<7박8일:PR>']
# ['<5일:PR>']
# ['<일주일:PR>']
# ['<4박 5일:PR>', '<5박6일:PR>']
# ['<2박3일:PR>']
# ['<3박 4일:PR>']
# ['<7~15일:PR>']
# ['<4박6일:PR>', '<5박6일:PR>']
# ['<3일 이상:PR>']
# ['<5박6일:PR>']
# ['<짧은 기간:PR>']
# ['<열흘 동안:PR>']
# ['<10일에서 14일:PR>']
# ['<4박5일:PR>']
# ['<맛있는게 많았으면:PR>']
# ['<3박4일:PR>']
# ['<5박6일:PR>']
# ['<5일:PR>']
# ['<4박5일:PR>']
# ['<10일:PR>']
# ['<3박4일:PR>', '<3박5일:PR>', '<4박5일:PR>', '<5일:PR>']
# ['<4박5일:PR>', '<5박6일:PR>']
# ['<5박6일:PR>']
# ['<3박:PR>', '<7박:PR>']
# ['<3박4일:PR>']
# ['<일주일:PR>']
# ['<2박3일:PR>']
# ['<4박5일:PR>']
# ['<5일:PR>']
# ['<2주간:PR>']
# ['<5일정도:PR>']
# ['<6박 8일:PR>']
# ['<2박3일:PR>', '<3박:PR>']
# ['<4박5일:PR>']
# ['<3~5일:PR>']
# ['<4박5일:PR>']
# ['<5일:PR>']
# ['<2박3일:PR>']
# ['<7~10일:PR>']
# ['<2박3일:PR>']
# ['<단기:PR>', '<3~5박:PR>']
# ['<3박4일:PR>']
# ['<4일~5일:PR>']
# ['<3박4일:PR>']
# ['<4일에서 7일:PR>']
# ['<3박4일:PR>']
# ['<3박4일:PR>']
# ['<10일:PR>']
# ['<3박5일:PR>', '<4박 5일:PR>']
# ['<5박6일:PR>']
# ['<2박3일:PR>', '<3박4일:PR>']
# ['<4박5일:PR>', '<6박7일:PR>']
# ['<4박 5일:PR>']
# ['<3박5일:PR>', '<4박6일:PR>']
# ['<5일:PR>']
# ['<3박4일:PR>']
# ['<3박4일:PR>']
# ['<3박4일:PR>', '<3박4일:PR>']
# ['<2박 3일:PR>']
# ['<6박7일:PR>']
# ['<2박3일:PR>', '<3박4일:PR>']
# ['<3박4일:PR>']
# ['<4박5일:PR>']
# ['<2박3일:PR>']
# ['<4박 5일:PR>']
# ['<2박3일:PR>']
# ['<5일:PR>']
# ['<3박4일:PR>']
# ['<5박6일:PR>']
# ['<4박5일:PR>', '<6박7일:PR>']
# ['<3박4일:PR>']
# ['<2박:PR>']
# ['<2박 3일:PR>', '<3박 4일:PR>']
# ['<4박6일:PR>']
# ['<3박5일:PR>']
# ['<3박:PR>']
# ['<3박 4일:PR>']
# ['<2박3일:PR>']
# ['<5일:PR>']
# ['<5박6일:PR>']
# ['<우기:WT>']
# ['<더운곳:WT>']
# ['<시원한:WT>']
# ['<따뜻한:WT>']
# ['<덥지 않은:WT>']
# ['<더운:WT>']
# ['<따뜻한:WT>']
# ['<선선:WT>']
# ['<시원한:WT>']
# ['<시원하게:WT>']
# ['<따뜻한:WT>']
# ['<시원하게:WT>']
# ['<따뜻한:WT>']
# ['<따뜻한:WT>']
# ['<더운:WT>']

# %%
"""
    Convert XML like(<tag>~</tag>) text data to N2N data format

    Author : Sangkeun Jung
"""
import os,sys, codecs

# add common to path
from pathlib import Path

common_path = str(Path( os.path.abspath("__file__") ).parent.parent.parent.parent)
print(common_path)
sys.path.append(common_path)

from common.data_format.n2n import parse_a_line

def convert(fn):
    xml_fn = os.path.join( os.path.dirname("__file__"), fn ) 
    to_fn  = os.path.join( os.path.dirname("__file__"), 'trip.n2n.txt' ) 

    with codecs.open(to_fn, 'w', encoding='utf-8') as of:
        with codecs.open(xml_fn, 'r', encoding='utf-8') as f:
            for line in f: 
                line = line.rstrip('\n\r')

                # convert xml like sentence to BIO tagged N2N format
                raw, tags = parse_a_line(line)

                for char, tag in zip(raw, tags):
                    print("{}\t{}".format(char, tag), file=of)
                print("-"*50, file=of)
            
    print("N2N file dumped at {}".format(to_fn))

if __name__ == '__main__':
    fn = 'trip.xml.txt'
    convert(fn)
# Out:
# C:\Users\tjdwn\pyNLP\course\nlp
# N2N file dumped at trip.n2n.txt
